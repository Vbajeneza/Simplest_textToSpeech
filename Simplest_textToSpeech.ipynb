# %% [markdown]
# ## Simplest Text to speech

# %%
import pyttsx3

# %%
txtToSpeech=pyttsx3.init() #creating object

text=input("")  #Enter text from user
txtToSpeech.say(text) 
txtToSpeech.save_to_file(text, 'test.mp3') #saving the audio file 

txtToSpeech.runAndWait()
# Out:
# This is the start
